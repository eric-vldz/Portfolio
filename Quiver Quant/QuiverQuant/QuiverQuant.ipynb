# %%
from live_congress_trading import live_congress_trading
df = live_congress_trading()
df
# Out:
#          Representative BioGuideID  ReportDate TransactionDate Ticker  \
# 0       Morgan Mcgarvey    M001220  2024-09-25      2024-08-19   AAPL
# 1       Morgan Mcgarvey    M001220  2024-09-25      2024-08-13   AAPL
# 2    William R. Keating    K000375  2024-09-24      2024-09-11   NXPI
# 3    William R. Keating    K000375  2024-09-24      2024-09-11    CAT
# 4    Michael C. Burgess    B001248  2024-09-24      2024-09-03   ILMN
# ..                  ...        ...         ...             ...    ...
# 995    Thomas R. Carper    C000174  2024-01-03      2023-12-18  SBPYX
# 996    Thomas R. Carper    C000174  2024-01-03      2023-12-18   XCEM
# 997    Thomas R. Carper    C000174  2024-01-03      2023-12-18   FDRR
# 998    Thomas R. Carper    C000174  2024-01-03      2023-12-18   XCEM
# 999    Thomas R. Carper    C000174  2024-01-03      2023-12-14   HDGE
#
#      Transaction              Range            House   Amount Party  \
# ...

# %%
df.to_excel('congress_trading.xlsx', index=False)
